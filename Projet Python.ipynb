# %%
import pandas as pd

# %%
ips = pd.read_csv('ips.csv')
lycee_pro = pd.read_csv('lycee_pro.csv')
specialites = pd.read_csv('specialites.csv')
valeur_ajoutee_gen = pd.read_csv('valeur_ajoutee_gen.csv', low_memory = False)
valeur_ajoutee_pro = pd.read_csv('valeur_ajoutee_pro.csv', low_memory = False)

# %%
display(ips)
display(lycee_pro)
display(specialites)
display(valeur_ajoutee_gen)
display(valeur_ajoutee_pro)
# Out:
#      rentree_scolaire       academie  code_du_departement   departement  \
# 0           2022-2023           LYON                    1           AIN
# 1           2022-2023           LYON                    1           AIN
# 2           2022-2023           LYON                    1           AIN
# 3           2022-2023           LYON                    1           AIN
# 4           2022-2023           LYON                    1           AIN
# ...               ...            ...                  ...           ...
# 3595        2022-2023  ORLEANS-TOURS                   28  EURE-ET-LOIR
# 3596        2022-2023         RENNES                   29     FINISTERE
# 3597        2022-2023         RENNES                   29     FINISTERE
# 3598        2022-2023         RENNES                   29     FINISTERE
# 3599        2022-2023         RENNES                   29     FINISTERE
#
#            uai                              nom_de_l_etablissment  \
# ...
